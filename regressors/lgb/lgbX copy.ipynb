# %%
import gc
import os
import itertools
import pickle
import re
import time
from random import choice, choices
from functools import reduce
from tqdm import tqdm
from itertools import cycle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from functools import reduce
from itertools import cycle
from scipy import stats
from scipy.stats import skew, kurtosis
from sklearn import metrics, model_selection, preprocessing, linear_model, ensemble, decomposition, tree
import lightgbm as lgb
import optuna
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split


import sys
sys.path.append('../../../')
from utils import *

# %% [markdown]
# ## Prepro: change names to numbers

# %%
train_feats = pd.read_csv('../../../feature_eng/output/train_double_corr_786feats.csv')
train_score = pd.read_csv('../../../data/train_scores.csv')

if 'score' not in train_feats.columns:
    train_feats = pd.merge(train_feats, train_score, on='id', how='left')

train_feats = train_feats[~train_feats['id'].isin(['3e10785d'])]
train_feats.replace([np.inf, -np.inf], np.nan, inplace=True)
cols = train_feats.columns

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(train_feats['score'])

score_transformed = le.transform(train_feats['score'])

# %% [markdown]
# ## Keep columns

# %%
# Options:
# "count_bursts", "word_sent_parag_agg", "pressed_keys", "paussed_features"
# "segments_visit", "paragraph_ratios", "time_gaps", "cursor_word_changes"
# "punctuation", "key_mouse", "time_feat", "fft", "avg_event_per_minute", 
# "avg_char_deletion_per_minute", "avg_char_insert_per_minute"
# "IKI_word", "IKI_sentence", "IKI_paragraph", "latencies", "IWD"
# "-idle"

endings_to_keep = ["idle", "count_bursts", "word_sent_parag_agg"]
endings_to_keep += ["id"]

dir_to_save = "lgb19"
stratification = True
n_jobs = 4
noise = True
data_augmentation = True

iterations = 5
n_splits = 4


try:
    os.mkdir(dir_to_save)
except:
    print('Already exists')
    sys.exit()

cols_to_keep = [col for col in train_feats.columns if col.endswith(tuple(endings_to_keep)) or col in ['id', 'score']]

with open(f'{dir_to_save}/feature_list.pkl', 'wb') as f:
    pickle.dump(cols_to_keep, f)

train_feats = train_feats[cols_to_keep]
print(len(train_feats.columns)-2)
# Out:
# 163

# %%
counter = 0
new_columns = {}
for col in cols:
    if col != 'id' and col != 'score':
        new_columns[col] = counter
        counter += 1

train_feats.rename(columns=new_columns, inplace=True)

# %%
target_col = ['score']
drop_cols = ['id']
train_cols = [col for col in train_feats.columns if col not in target_col + drop_cols]

# %%
def data_augmentation(x, y, pct=0.75, scale=0.05):
    # Determine the number of rows to create
    num_rows = x.shape[0]
    num_new_rows = int(num_rows * pct)

    # Randomly select rows from the original DataFrame
    indices = np.random.choice(x.index, size=num_new_rows)
    new_rows_x = x.loc[indices]

    # Add Gaussian noise to each numerical column
    for col in new_rows_x.select_dtypes(include=[np.number]).columns:
        noise = np.random.normal(loc=0.0, scale=scale, size=num_new_rows)
        new_rows_x[col] += new_rows_x[col] * noise

    # Append the new rows to the original DataFrame
    x = pd.concat([x, new_rows_x], ignore_index=True)

    # Do the same for y
    new_rows_y = y.loc[indices]
    y = pd.concat([y, new_rows_y], ignore_index=True)

    return x, y

# %%
def objective(trial,train_x,train_y,val_x,val_y,RANDOM_STATE=41, data_augmentation=False):

    params = {
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-4, 10.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-4, 10.0, log=True),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1), #trial.suggest_categorical('colsample_bytree', [0.4,0.7,1.0]),
        'colsample_bynode': trial.suggest_float('colsample_bynode', 0.5, 1), #trial.suggest_categorical('colsample_bynode', [0.4,0.7,1.0]),
        'subsample': trial.suggest_float('subsample', 0.5, 1),# trial.suggest_categorical('subsample', [0.4,0.7,1.0]),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 5e-2, log=True), #trial.suggest_categorical('learning_rate', [0.008,0.01,0.012,0.014,0.016,0.018, 0.02]),
        'max_depth': trial.suggest_categorical('max_depth', [5,7,9,11,13,15,17,20]),
        'min_child_samples': trial.suggest_categorical('min_child_samples', [7,9,11,13,15,17,20]),
        'num_leaves': trial.suggest_int('num_leaves', 10, 38, step=4),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1900, step=200),
    }

    all_params = {
        "objective": "rmse",
        "metric": "rmse",
        'random_state': RANDOM_STATE,
        "verbosity": -1,
        "n_jobs": n_jobs,
        **params
    }

    model = lgb.LGBMRegressor(**all_params)

    if data_augmentation:
        train_x, train_y = data_augmentation(train_x, train_y, pct=0.75, scale=0.05)
    
    model.fit(train_x, train_y)
    
    preds = model.predict(val_x)
    
    rmse = mean_squared_error(val_y, preds, squared=False)
    
    return rmse

# %%
def lgb_calc_OOF(x_train, y_train, x_valid, y_valid, iter, split, RANDOM_STATE=42, noise=False, data_augmentation=False):
    # split into two validations
    x_valid1, x_valid2, y_valid1, y_valid2 = train_test_split(x_valid, y_valid, test_size=0.5, random_state=RANDOM_STATE, shuffle=False)

    '''Use v1, test on v2'''

    # Bayesian Opt using v1
    study = optuna.create_study(direction='minimize')
    study.optimize(lambda trial: objective(trial, x_train, y_train, x_valid1, y_valid1,RANDOM_STATE,data_augmentation), n_trials=20)
    best_trial1 = study.best_trial.params

    # Get best params
    best_params = {
        "objective": "rmse",
        "metric": "rmse",
        'random_state': RANDOM_STATE,
        "verbosity": -1,
        "n_jobs": n_jobs,
        **best_trial1
    }
        
    model = lgb.LGBMRegressor(**best_params)
    if data_augmentation:
        x_train, y_train = data_augmentation(x_train, y_train, pct=0.75, scale=0.05)
    if noise:
        y_train = y_train + np.random.normal(0, 0.25, y_train.shape)
    model.fit(x_train, y_train)
    model.booster_.save_model(f'./{dir_to_save}/lgb_iter{iter}_split{split}_val1.txt')

    # Predict on v2
    valid2_predict = model.predict(x_valid2)


    '''Use v2, test on v1'''

    # Bayesian Opt using v2
    study = optuna.create_study(direction='minimize')
    study.optimize(lambda trial: objective(trial, x_train, y_train, x_valid2, y_valid2,RANDOM_STATE,data_augmentation), n_trials=20)
    best_trial2 = study.best_trial.params

    # Get best params
    best_params = {
        "objective": "rmse",
        "metric": "rmse",
        'random_state': RANDOM_STATE,
        "verbosity": -1,
        "n_jobs": n_jobs,
        **best_trial2
    }
        
    model = lgb.LGBMRegressor(**best_params)
    if data_augmentation:
        x_train, y_train = data_augmentation(x_train, y_train, pct=0.75, scale=0.05)
    if noise:
        y_train = y_train + np.random.normal(0, 0.25, y_train.shape)
    model.fit(x_train, y_train)
    model.booster_.save_model(f'./{dir_to_save}/lgb_iter{iter}_split{split}_val2.txt')

    # Predict on v1
    valid1_predict = model.predict(x_valid1)

    # Return OOFs
    return np.concatenate([valid1_predict,valid2_predict])

# %%
OOF_SCORE = np.zeros(len(train_feats))

models_dict = {}
preds_dict = {}
count = 0
for _ in train_feats['id'].unique():
    preds_dict[count] = []
    count+=1

for i in range(iterations):

    if stratification:
        kf = model_selection.StratifiedKFold(n_splits=n_splits, random_state=41 + i, shuffle=True)
        j = 0
        for fold, (train_idx, valid_idx) in enumerate(kf.split(train_feats, score_transformed)):
            
            X_train, y_train = train_feats.iloc[train_idx][train_cols], train_feats.iloc[train_idx][target_col]
            X_valid, y_valid = train_feats.iloc[valid_idx][train_cols], train_feats.iloc[valid_idx][target_col]

            valid_predict = lgb_calc_OOF(X_train, y_train, X_valid, y_valid, i, j, RANDOM_STATE=41 + i, noise=noise, data_augmentation=data_augmentation)

            OOF_SCORE[valid_idx] += valid_predict / iterations
            j+=1

    else:
        kf = model_selection.KFold(n_splits=n_splits, random_state=41 + i, shuffle=True)
        j = 0
        for fold, (train_idx, valid_idx) in enumerate(kf.split(train_feats)):
            
            X_train, y_train = train_feats.iloc[train_idx][train_cols], train_feats.iloc[train_idx][target_col]
            X_valid, y_valid = train_feats.iloc[valid_idx][train_cols], train_feats.iloc[valid_idx][target_col]

            valid_predict = lgb_calc_OOF(X_train, y_train, X_valid, y_valid, i, j, RANDOM_STATE=41 + i, noise=noise, data_augmentation=data_augmentation)

            OOF_SCORE[valid_idx] += valid_predict / iterations
            j+=1
# Out:
# [I 2024-01-02 23:10:00,910] A new study created in memory with name: no-name-564be9d8-8279-4bdd-9c90-7936dcd451e3
# [I 2024-01-02 23:10:04,900] Trial 0 finished with value: 0.6417844937652178 and parameters: {'reg_lambda': 5.735407414824867, 'reg_alpha': 3.485050502596975, 'colsample_bytree': 0.9292488066648907, 'colsample_bynode': 0.7914748322867119, 'subsample': 0.9880305389951333, 'learning_rate': 0.001585497320700013, 'max_depth': 15, 'min_child_samples': 20, 'num_leaves': 14, 'n_estimators': 1500}. Best is trial 0 with value: 0.6417844937652178.
# [I 2024-01-02 23:10:08,331] Trial 1 finished with value: 0.6823934222924439 and parameters: {'reg_lambda': 7.459438308749577, 'reg_alpha': 1.6290353760144394, 'colsample_bytree': 0.8075336280346261, 'colsample_bynode': 0.9359778171275309, 'subsample': 0.8712927964402234, 'learning_rate': 0.0015932813664262162, 'max_depth': 13, 'min_child_samples': 17, 'num_leaves': 26, 'n_estimators': 900}. Best is trial 0 with value: 0.6417844937652178.
# [I 2024-01-02 23:10:11,083] Trial 2 finished with value: 0.6249516955400704 and parameters: {'reg_lambda': 0.23095049173004914, 'reg_alpha': 0.7893549033994781, 'colsample_bytree': 0.5483410146269752, 'colsample_bynode': 0.8330712271102139, 'subsample': 0.8352052545651265, 'learning_rate': 0.010829260553486554, 'max_depth': 5, 'min_child_samples': 20, 'num_leaves': 34, 'n_estimators': 1300}. Best is trial 2 with value: 0.6249516955400704.
# [I 2024-01-02 23:10:12,432] Trial 3 finished with value: 0.8765672683682277 and parameters: {'reg_lambda': 0.0004485004687799127, 'reg_alpha': 0.0028578031782280355, 'colsample_bytree': 0.7479838500649922, 'colsample_bynode': 0.8258413304767598, 'subsample': 0.6334813404047823, 'learning_rate': 0.0009754996736188422, 'max_depth': 7, 'min_child_samples': 13, 'num_leaves': 18, 'n_estimators': 300}. Best is trial 2 with value: 0.6249516955400704.
# [I 2024-01-02 23:10:15,491] Trial 4 finished with value: 0.9258656773812317 and parameters: {'reg_lambda': 0.00046861596377335737, 'reg_alpha': 0.5337793407093694, 'colsample_bytree': 0.6776913864883904, 'colsample_bynode': 0.9468476000830648, 'subsample': 0.7794618633932497, 'learning_rate': 0.00019641700607575844, 'max_depth': 17, 'min_child_samples': 15, 'num_leaves': 18, 'n_estimators': 900}. Best is trial 2 with value: 0.6249516955400704.
# [I 2024-01-02 23:10:23,407] Trial 5 finished with value: 0.6514908880863184 and parameters: {'reg_lambda': 3.7585824540918624, 'reg_alpha': 7.998903680315214, 'colsample_bytree': 0.9072593699626179, 'colsample_bynode': 0.779896122439773, 'subsample': 0.9104588392471517, 'learning_rate': 0.003152896695840964, 'max_depth': 13, 'min_child_samples': 15, 'num_leaves': 38, 'n_estimators': 1900}. Best is trial 2 with value: 0.6249516955400704.
# [I 2024-01-02 23:10:28,023] Trial 6 finished with value: 0.7181054040169849 and parameters: {'reg_lambda': 0.21599878683084775, 'reg_alpha': 0.0006699951464043708, 'colsample_bytree': 0.7232898179426193, 'colsample_bynode': 0.6283599896388576, 'subsample': 0.5796403325567023, 'learning_rate': 0.0009415864205110787, 'max_depth': 7, 'min_child_samples': 17, 'num_leaves': 34, 'n_estimators': 900}. Best is trial 2 with value: 0.6249516955400704.
# [I 2024-01-02 23:10:29,158] Trial 7 finished with value: 0.6353228381455145 and parameters: {'reg_lambda': 0.00012799813848695963, 'reg_alpha': 0.02476053400066288, 'colsample_bytree': 0.9830116964068865, 'colsample_bynode': 0.6626010547731214, 'subsample': 0.6986299138004743, 'learning_rate': 0.0412493460784757, 'max_depth': 11, 'min_child_samples': 7, 'num_leaves': 18, 'n_estimators': 300}. Best is trial 2 with value: 0.6249516955400704.
# [I 2024-01-02 23:10:31,165] Trial 8 finished with value: 0.6122321348998635 and parameters: {'reg_lambda': 0.0006019505627370462, 'reg_alpha': 0.081404241782697, 'colsample_bytree': 0.5591038103557177, 'colsample_bynode': 0.7748529546669644, 'subsample': 0.7303472372718554, 'learning_rate': 0.03341729844124445, 'max_depth': 15, 'min_child_samples': 7, 'num_leaves': 34, 'n_estimators': 500}. Best is trial 8 with value: 0.6122321348998635.
# [I 2024-01-02 23:10:33,810] Trial 9 finished with value: 0.6405524348066085 and parameters: {'reg_lambda': 4.723473384537005, 'reg_alpha': 4.720960585814047, 'colsample_bytree': 0.7082919276328091, 'colsample_bynode': 0.7031004825595493, 'subsample': 0.6796342468516671, 'learning_rate': 0.03136210948727495, 'max_depth': 9, 'min_child_samples': 7, 'num_leaves': 34, 'n_estimators': 1100}. Best is trial 8 with value: 0.6122321348998635.
# [I 2024-01-02 23:10:34,242] Trial 10 finished with value: 0.7078934381241404 and parameters: {'reg_lambda': 0.0034974126291110745, 'reg_alpha': 0.06177866244030716, 'colsample_bytree': 0.5043780123466693, 'colsample_bynode': 0.5115678037448652, 'subsample': 0.5439548844797578, 'learning_rate': 0.009910540775777627, 'max_depth': 15, 'min_child_samples': 11, 'num_leaves': 26, 'n_estimators': 100}. Best is trial 8 with value: 0.6122321348998635.
# [I 2024-01-02 23:10:36,349] Trial 11 finished with value: 0.6285650088539193 and parameters: {'reg_lambda': 0.02565783507504367, 'reg_alpha': 0.16459698701176237, 'colsample_bytree': 0.5090658945765749, 'colsample_bynode': 0.8655812807507636, 'subsample': 0.7804768178810274, 'learning_rate': 0.016420697180477006, 'max_depth': 5, 'min_child_samples': 20, 'num_leaves': 30, 'n_estimators': 1300}. Best is trial 8 with value: 0.6122321348998635.
# [I 2024-01-02 23:10:38,142] Trial 12 finished with value: 0.6292329066201203 and parameters: {'reg_lambda': 0.08259323767105033, 'reg_alpha': 0.23413657114504585, 'colsample_bytree': 0.5825495728444352, 'colsample_bynode': 0.8715236079104459, 'subsample': 0.7955305217013063, 'learning_rate': 0.00950879095511165, 'max_depth': 5, 'min_child_samples': 9, 'num_leaves': 38, 'n_estimators': 700}. Best is trial 8 with value: 0.6122321348998635.
# [I 2024-01-02 23:10:44,099] Trial 13 finished with value: 0.6355311696036097 and parameters: {'reg_lambda': 0.009279825583925684, 'reg_alpha': 0.020804293686321834, 'colsample_bytree': 0.589077589959635, 'colsample_bynode': 0.9897310532827117, 'subsample': 0.719701566231006, 'learning_rate': 0.04136461526756587, 'max_depth': 20, 'min_child_samples': 20, 'num_leaves': 30, 'n_estimators': 1700}. Best is trial 8 with value: 0.6122321348998635.
# [I 2024-01-02 23:10:45,485] Trial 14 finished with value: 0.6108356855721527 and parameters: {'reg_lambda': 0.28278245190482604, 'reg_alpha': 0.7168761601377899, 'colsample_bytree': 0.6209050568643529, 'colsample_bynode': 0.7394710531307962, 'subsample': 0.8392391464222859, 'learning_rate': 0.01386843125140047, 'max_depth': 5, 'min_child_samples': 7, 'num_leaves': 34, 'n_estimators': 500}. Best is trial 14 with value: 0.6108356855721527.
# [I 2024-01-02 23:10:47,983] Trial 15 finished with value: 0.6340538340797743 and parameters: {'reg_lambda': 0.0031553900674603534, 'reg_alpha': 0.12040707062215665, 'colsample_bytree': 0.6432667252163, 'colsample_bynode': 0.7293160863419548, 'subsample': 0.7463736140657848, 'learning_rate': 0.020364761061083383, 'max_depth': 15, 'min_child_samples': 7, 'num_leaves': 30, 'n_estimators': 500}. Best is trial 14 with value: 0.6108356855721527.
# [I 2024-01-02 23:10:48,958] Trial 16 finished with value: 0.6473540564383442 and parameters: {'reg_lambda': 0.44223626812895417, 'reg_alpha': 0.010477034397655951, 'colsample_bytree': 0.6274548000741988, 'colsample_bynode': 0.7370536089903281, 'subsample': 0.6450109334236257, 'learning_rate': 0.004489805935387489, 'max_depth': 20, 'min_child_samples': 7, 'num_leaves': 10, 'n_estimators': 500}. Best is trial 14 with value: 0.6108356855721527.
# [I 2024-01-02 23:10:49,662] Trial 17 finished with value: 0.6176319051731383 and parameters: {'reg_lambda': 0.02791341011484384, 'reg_alpha': 0.46646319826725435, 'colsample_bytree': 0.619101373058797, 'colsample_bynode': 0.6613308165128483, 'subsample': 0.8274707909722249, 'learning_rate': 0.04560307510092406, 'max_depth': 17, 'min_child_samples': 7, 'num_leaves': 38, 'n_estimators': 100}. Best is trial 14 with value: 0.6108356855721527.
# [I 2024-01-02 23:10:51,358] Trial 18 finished with value: 0.6257247857333268 and parameters: {'reg_lambda': 0.8959970691013812, 'reg_alpha': 0.00010439335494692506, 'colsample_bytree': 0.5541819920979544, 'colsample_bynode': 0.7695376360851234, 'subsample': 0.5097780004025821, 'learning_rate': 0.0055049563990571685, 'max_depth': 11, 'min_child_samples': 11, 'num_leaves': 22, 'n_estimators': 500}. Best is trial 14 with value: 0.6108356855721527.
# [I 2024-01-02 23:10:53,975] Trial 19 finished with value: 0.6199431149161294 and parameters: {'reg_lambda': 0.07701676450043207, 'reg_alpha': 1.1784426478463426, 'colsample_bytree': 0.6645406564222854, 'colsample_bynode': 0.6033962666724291, 'subsample': 0.7324763664894998, 'learning_rate': 0.023324438771515084, 'max_depth': 9, 'min_child_samples': 13, 'num_leaves': 34, 'n_estimators': 700}. Best is trial 14 with value: 0.6108356855721527.
# [I 2024-01-02 23:10:55,139] A new study created in memory with name: no-name-45761567-50f1-4f29-a4e0-e907d92eae26
# [I 2024-01-02 23:10:56,184] Trial 0 finished with value: 0.6269156245898889 and parameters: {'reg_lambda': 2.6213475443201477, 'reg_alpha': 1.1802407969101576, 'colsample_bytree': 0.892059605902779, 'colsample_bynode': 0.7591318900365815, 'subsample': 0.6600476607813786, 'learning_rate': 0.011821904895797954, 'max_depth': 20, 'min_child_samples': 11, 'num_leaves': 14, 'n_estimators': 300}. Best is trial 0 with value: 0.6269156245898889.
# [I 2024-01-02 23:10:56,567] Trial 1 finished with value: 1.0040660713239624 and parameters: {'reg_lambda': 0.8467717108057851, 'reg_alpha': 0.000896353993313926, 'colsample_bytree': 0.5173688240813115, 'colsample_bynode': 0.8317587568152947, 'subsample': 0.661400163973165, 'learning_rate': 0.0004177943456416936, 'max_depth': 9, 'min_child_samples': 9, 'num_leaves': 14, 'n_estimators': 100}. Best is trial 0 with value: 0.6269156245898889.
# [I 2024-01-02 23:10:56,899] Trial 2 finished with value: 0.8922426595633806 and parameters: {'reg_lambda': 0.26546003037500154, 'reg_alpha': 0.016325667705534515, 'colsample_bytree': 0.6244216657491002, 'colsample_bynode': 0.7768006878635225, 'subsample': 0.5365299322968691, 'learning_rate': 0.002846781949094743, 'max_depth': 5, 'min_child_samples': 7, 'num_leaves': 14, 'n_estimators': 100}. Best is trial 0 with value: 0.6269156245898889.
# [I 2024-01-02 23:10:57,910] Trial 3 finished with value: 0.628906473531266 and parameters: {'reg_lambda': 0.001683793623063374, 'reg_alpha': 0.00023837280007155457, 'colsample_bytree': 0.7831551687457003, 'colsample_bynode': 0.6343747759549319, 'subsample': 0.6629497922269112, 'learning_rate': 0.010979925123901892, 'max_depth': 5, 'min_child_samples': 15, 'num_leaves': 30, 'n_estimators': 300}. Best is trial 0 with value: 0.6269156245898889.
# [I 2024-01-02 23:10:59,553] Trial 4 finished with value: 0.9305438883931496 and parameters: {'reg_lambda': 0.05769628951806588, 'reg_alpha': 0.13350062132656354, 'colsample_bytree': 0.7378736647326798, 'colsample_bynode': 0.9578535507717704, 'subsample': 0.8597166950532892, 'learning_rate': 0.0006249538550050411, 'max_depth': 7, 'min_child_samples': 13, 'num_leaves': 30, 'n_estimators': 300}. Best is trial 0 with value: 0.6269156245898889.
# [I 2024-01-02 23:11:02,872] Trial 5 finished with value: 0.6372837017190355 and parameters: {'reg_lambda': 0.017319601355194832, 'reg_alpha': 0.00022202412051105326, 'colsample_bytree': 0.742950286675458, 'colsample_bynode': 0.6086865368359407, 'subsample': 0.5915612332907279, 'learning_rate': 0.002885470406700428, 'max_depth': 5, 'min_child_samples': 9, 'num_leaves': 30, 'n_estimators': 1100}. Best is trial 0 with value: 0.6269156245898889.
# [I 2024-01-02 23:11:04,620] Trial 6 finished with value: 0.6248924107812459 and parameters: {'reg_lambda': 4.808230589913552, 'reg_alpha': 0.422841360621926, 'colsample_bytree': 0.8471380533824618, 'colsample_bynode': 0.7073902230071631, 'subsample': 0.8709666182264844, 'learning_rate': 0.006437741175738011, 'max_depth': 5, 'min_child_samples': 9, 'num_leaves': 10, 'n_estimators': 900}. Best is trial 6 with value: 0.6248924107812459.
# [I 2024-01-02 23:11:12,962] Trial 7 finished with value: 0.8726372512253259 and parameters: {'reg_lambda': 0.0009207725045186875, 'reg_alpha': 0.11183290814984412, 'colsample_bytree': 0.9991373926040521, 'colsample_bynode': 0.6657511059656762, 'subsample': 0.7941241934397154, 'learning_rate': 0.00024351935913643957, 'max_depth': 7, 'min_child_samples': 17, 'num_leaves': 30, 'n_estimators': 1300}. Best is trial 6 with value: 0.6248924107812459.
# [I 2024-01-02 23:11:20,794] Trial 8 finished with value: 0.9172420457949826 and parameters: {'reg_lambda': 1.0374816412600947, 'reg_alpha': 0.045858058904550705, 'colsample_bytree': 0.7838477873972981, 'colsample_bynode': 0.5578730757049895, 'subsample': 0.5966700928859274, 'learning_rate': 0.00014488619571266132, 'max_depth': 11, 'min_child_samples': 20, 'num_leaves': 22, 'n_estimators': 1500}. Best is trial 6 with value: 0.6248924107812459.
# [I 2024-01-02 23:11:23,339] Trial 9 finished with value: 0.6290080874630585 and parameters: {'reg_lambda': 0.00305304635002577, 'reg_alpha': 0.00024215418543607506, 'colsample_bytree': 0.5488352617998606, 'colsample_bynode': 0.5992921888762293, 'subsample': 0.9807303637107674, 'learning_rate': 0.014040802149842727, 'max_depth': 17, 'min_child_samples': 11, 'num_leaves': 22, 'n_estimators': 700}. Best is trial 6 with value: 0.6248924107812459.
# [I 2024-01-02 23:11:27,030] Trial 10 finished with value: 0.6247820139828533 and parameters: {'reg_lambda': 5.6159679795680395, 'reg_alpha': 5.200126244106096, 'colsample_bytree': 0.8902180541402135, 'colsample_bynode': 0.5282666577791598, 'subsample': 0.8737876869769096, 'learning_rate': 0.04600736627892625, 'max_depth': 15, 'min_child_samples': 9, 'num_leaves': 38, 'n_estimators': 1900}. Best is trial 10 with value: 0.6247820139828533.
# [I 2024-01-02 23:11:29,646] Trial 11 finished with value: 0.6355952071084762 and parameters: {'reg_lambda': 8.938739871879692, 'reg_alpha': 9.79497276588008, 'colsample_bytree': 0.882292205851216, 'colsample_bynode': 0.5033175317213352, 'subsample': 0.8738805370099272, 'learning_rate': 0.045448647426423246, 'max_depth': 15, 'min_child_samples': 9, 'num_leaves': 38, 'n_estimators': 1900}. Best is trial 10 with value: 0.6247820139828533.
# [I 2024-01-02 23:11:32,526] Trial 12 finished with value: 0.6241886541840787 and parameters: {'reg_lambda': 9.309109086073779, 'reg_alpha': 8.440943270049655, 'colsample_bytree': 0.881299159633281, 'colsample_bynode': 0.6931712287806286, 'subsample': 0.9468131830720008, 'learning_rate': 0.0462583241067131, 'max_depth': 13, 'min_child_samples': 9, 'num_leaves': 38, 'n_estimators': 1900}. Best is trial 12 with value: 0.6241886541840787.
# [I 2024-01-02 23:11:35,702] Trial 13 finished with value: 0.6281647717073277 and parameters: {'reg_lambda': 8.448627033674148, 'reg_alpha': 7.729404431419898, 'colsample_bytree': 0.9688870046499894, 'colsample_bynode': 0.5049278419448137, 'subsample': 0.996543957472189, 'learning_rate': 0.04084120172724201, 'max_depth': 13, 'min_child_samples': 9, 'num_leaves': 38, 'n_estimators': 1900}. Best is trial 12 with value: 0.6241886541840787.
# [I 2024-01-02 23:11:40,442] Trial 14 finished with value: 0.6387362920716536 and parameters: {'reg_lambda': 0.2714994391501693, 'reg_alpha': 2.2923438636995823, 'colsample_bytree': 0.924852753233586, 'colsample_bynode': 0.7067375826695286, 'subsample': 0.9380823662789889, 'learning_rate': 0.049994167792591894, 'max_depth': 15, 'min_child_samples': 13, 'num_leaves': 38, 'n_estimators': 1700}. Best is trial 12 with value: 0.6241886541840787.
# [I 2024-01-02 23:11:47,750] Trial 15 finished with value: 0.629335571455011 and parameters: {'reg_lambda': 1.6385555227026165, 'reg_alpha': 2.485144852893024, 'colsample_bytree': 0.8435391370243577, 'colsample_bynode': 0.5612889532603187, 'subsample': 0.7900796813360121, 'learning_rate': 0.01833405367510154, 'max_depth': 13, 'min_child_samples': 17, 'num_leaves': 34, 'n_estimators': 1500}. Best is trial 12 with value: 0.6241886541840787.
# [I 2024-01-02 23:11:52,173] Trial 16 finished with value: 0.6282709089089669 and parameters: {'reg_lambda': 9.943714454079174, 'reg_alpha': 9.568596873976308, 'colsample_bytree': 0.9344758420449073, 'colsample_bynode': 0.6731072760274198, 'subsample': 0.9273461160456996, 'learning_rate': 0.0262628516568849, 'max_depth': 15, 'min_child_samples': 7, 'num_leaves': 34, 'n_estimators': 1700}. Best is trial 12 with value: 0.6241886541840787.
# [I 2024-01-02 23:12:01,630] Trial 17 finished with value: 0.6163972221920211 and parameters: {'reg_lambda': 0.00014411322950658037, 'reg_alpha': 0.9499244622975773, 'colsample_bytree': 0.9996103833511639, 'colsample_bynode': 0.8233096227177771, 'subsample': 0.9165073071632022, 'learning_rate': 0.0060514627337196775, 'max_depth': 13, 'min_child_samples': 15, 'num_leaves': 26, 'n_estimators': 1900}. Best is trial 17 with value: 0.6163972221920211.
# [I 2024-01-02 23:12:08,330] Trial 18 finished with value: 0.6309606547617314 and parameters: {'reg_lambda': 0.00011440987946384059, 'reg_alpha': 0.7765353705514436, 'colsample_bytree': 0.9975446433203436, 'colsample_bynode': 0.8347962916775132, 'subsample': 0.9394722223047307, 'learning_rate': 0.006658658267076768, 'max_depth': 13, 'min_child_samples': 15, 'num_leaves': 26, 'n_estimators': 1300}. Best is trial 17 with value: 0.6163972221920211.
# [I 2024-01-02 23:12:15,062] Trial 19 finished with value: 0.6313647319463642 and parameters: {'reg_lambda': 0.020517700165115175, 'reg_alpha': 0.3782255629886448, 'colsample_bytree': 0.9431854685298161, 'colsample_bynode': 0.8096667671169866, 'subsample': 0.9960262305884333, 'learning_rate': 0.001750193686113732, 'max_depth': 13, 'min_child_samples': 15, 'num_leaves': 18, 'n_estimators': 1700}. Best is trial 17 with value: 0.6163972221920211.
# [I 2024-01-02 23:12:24,506] A new study created in memory with name: no-name-c9acc564-3d4f-42c0-b1a3-70703dddd880
# [I 2024-01-02 23:12:26,189] Trial 0 finished with value: 0.6654553953840354 and parameters: {'reg_lambda': 0.4011781495416823, 'reg_alpha': 0.0042142890814232566, 'colsample_bytree': 0.7456535103423729, 'colsample_bynode': 0.5831765906225397, 'subsample': 0.9605886262711134, 'learning_rate': 0.03066902129602325, 'max_depth': 5, 'min_child_samples': 17, 'num_leaves': 34, 'n_estimators': 900}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:28,736] Trial 1 finished with value: 0.6801846185172381 and parameters: {'reg_lambda': 0.007120992227010008, 'reg_alpha': 0.0006961540419610474, 'colsample_bytree': 0.9276213267442253, 'colsample_bynode': 0.7136688812573642, 'subsample': 0.690244302191856, 'learning_rate': 0.04526988168571806, 'max_depth': 17, 'min_child_samples': 20, 'num_leaves': 26, 'n_estimators': 700}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:32,634] Trial 2 finished with value: 0.8895246544161621 and parameters: {'reg_lambda': 0.18747920591094105, 'reg_alpha': 0.01637838165046518, 'colsample_bytree': 0.7509277448964348, 'colsample_bynode': 0.6790465320772667, 'subsample': 0.5285269984150566, 'learning_rate': 0.00041170719716382957, 'max_depth': 20, 'min_child_samples': 9, 'num_leaves': 30, 'n_estimators': 900}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:34,834] Trial 3 finished with value: 0.8159635687319966 and parameters: {'reg_lambda': 0.19854868866617556, 'reg_alpha': 0.0003131290741469564, 'colsample_bytree': 0.7041121673625852, 'colsample_bynode': 0.7031940400642103, 'subsample': 0.5519818385176111, 'learning_rate': 0.000520307072046698, 'max_depth': 17, 'min_child_samples': 11, 'num_leaves': 10, 'n_estimators': 1300}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:42,962] Trial 4 finished with value: 0.6701674530531504 and parameters: {'reg_lambda': 0.016694799107992465, 'reg_alpha': 0.023064961351867624, 'colsample_bytree': 0.7536384848649944, 'colsample_bynode': 0.8650474932664431, 'subsample': 0.5920923570878831, 'learning_rate': 0.008034087604799638, 'max_depth': 17, 'min_child_samples': 20, 'num_leaves': 38, 'n_estimators': 1900}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:45,445] Trial 5 finished with value: 0.6830005954115613 and parameters: {'reg_lambda': 0.00013276832531228429, 'reg_alpha': 0.04102400857480598, 'colsample_bytree': 0.9881338042377452, 'colsample_bynode': 0.7319911226861399, 'subsample': 0.8293330162518908, 'learning_rate': 0.042672389870778496, 'max_depth': 5, 'min_child_samples': 9, 'num_leaves': 14, 'n_estimators': 1300}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:47,200] Trial 6 finished with value: 0.6690164605613762 and parameters: {'reg_lambda': 0.7861405406010619, 'reg_alpha': 5.860215534163519, 'colsample_bytree': 0.540992372593404, 'colsample_bynode': 0.5908930824606364, 'subsample': 0.6922842942546976, 'learning_rate': 0.011248723803680395, 'max_depth': 17, 'min_child_samples': 15, 'num_leaves': 34, 'n_estimators': 700}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:55,449] Trial 7 finished with value: 0.7407977151698455 and parameters: {'reg_lambda': 0.01724492604336004, 'reg_alpha': 0.11535666592587443, 'colsample_bytree': 0.6783334509672013, 'colsample_bynode': 0.9749276979249781, 'subsample': 0.6770408485443222, 'learning_rate': 0.000599188521189576, 'max_depth': 11, 'min_child_samples': 11, 'num_leaves': 38, 'n_estimators': 1700}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:57,328] Trial 8 finished with value: 0.6766673366340726 and parameters: {'reg_lambda': 1.1017222813962397, 'reg_alpha': 0.000831277542986164, 'colsample_bytree': 0.5193960133627163, 'colsample_bynode': 0.6172009136703753, 'subsample': 0.7413706464943131, 'learning_rate': 0.023528841686749298, 'max_depth': 5, 'min_child_samples': 20, 'num_leaves': 14, 'n_estimators': 1700}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:57,711] Trial 9 finished with value: 0.7295830181365969 and parameters: {'reg_lambda': 0.17650496693152878, 'reg_alpha': 2.399648042010141, 'colsample_bytree': 0.9366343026817425, 'colsample_bynode': 0.5523625254050202, 'subsample': 0.7801538328325137, 'learning_rate': 0.011792145123804136, 'max_depth': 5, 'min_child_samples': 15, 'num_leaves': 34, 'n_estimators': 100}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:58,124] Trial 10 finished with value: 0.9343889653973865 and parameters: {'reg_lambda': 7.664884494055846, 'reg_alpha': 0.00346954932182345, 'colsample_bytree': 0.8425630153144901, 'colsample_bynode': 0.513379690978257, 'subsample': 0.9969344938322223, 'learning_rate': 0.0027050856735591346, 'max_depth': 9, 'min_child_samples': 17, 'num_leaves': 26, 'n_estimators': 100}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:12:59,731] Trial 11 finished with value: 0.6726061324229281 and parameters: {'reg_lambda': 8.301276117303303, 'reg_alpha': 2.6560311446430473, 'colsample_bytree': 0.5059535256358315, 'colsample_bynode': 0.5890602945904184, 'subsample': 0.9098908333366891, 'learning_rate': 0.007524724458777755, 'max_depth': 13, 'min_child_samples': 7, 'num_leaves': 30, 'n_estimators': 500}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:13:01,064] Trial 12 finished with value: 1.0350842147148007 and parameters: {'reg_lambda': 1.2616201496249602, 'reg_alpha': 8.740624855333541, 'colsample_bytree': 0.6044342765063069, 'colsample_bynode': 0.5065099942375425, 'subsample': 0.8567629646276527, 'learning_rate': 0.00011465144101793354, 'max_depth': 15, 'min_child_samples': 13, 'num_leaves': 34, 'n_estimators': 500}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:13:03,592] Trial 13 finished with value: 0.6713497427023734 and parameters: {'reg_lambda': 0.9799517073486349, 'reg_alpha': 0.257742003697068, 'colsample_bytree': 0.6028334613143774, 'colsample_bynode': 0.6357638440182065, 'subsample': 0.9800853344027247, 'learning_rate': 0.01598777584824869, 'max_depth': 7, 'min_child_samples': 15, 'num_leaves': 22, 'n_estimators': 1100}. Best is trial 0 with value: 0.6654553953840354.
# [I 2024-01-02 23:13:06,030] Trial 14 finished with value: 0.6609567164843508 and parameters: {'reg_lambda': 0.07952354899375698, 'reg_alpha': 0.00013696150862448008, 'colsample_bytree': 0.8131841596461787, 'colsample_bynode': 0.5862552902678482, 'subsample': 0.9151884664176576, 'learning_rate': 0.00714637935382899, 'max_depth': 13, 'min_child_samples': 17, 'num_leaves': 22, 'n_estimators': 700}. Best is trial 14 with value: 0.6609567164843508.
# [I 2024-01-02 23:13:09,675] Trial 15 finished with value: 0.6696909351590973 and parameters: {'reg_lambda': 0.06154703092061531, 'reg_alpha': 0.00016959950241781017, 'colsample_bytree': 0.8192897435911397, 'colsample_bynode': 0.7806153996567056, 'subsample': 0.9138894644996348, 'learning_rate': 0.004214137226679134, 'max_depth': 13, 'min_child_samples': 17, 'num_leaves': 22, 'n_estimators': 1100}. Best is trial 14 with value: 0.6609567164843508.
# [I 2024-01-02 23:13:10,968] Trial 16 finished with value: 0.6718240911988221 and parameters: {'reg_lambda': 0.005497695516818252, 'reg_alpha': 0.00241059146046079, 'colsample_bytree': 0.8115931717281948, 'colsample_bynode': 0.6358328310463031, 'subsample': 0.9339642377232373, 'learning_rate': 0.029029686788431326, 'max_depth': 13, 'min_child_samples': 17, 'num_leaves': 18, 'n_estimators': 500}. Best is trial 14 with value: 0.6609567164843508.
# [I 2024-01-02 23:13:14,344] Trial 17 finished with value: 0.6714654661851509 and parameters: {'reg_lambda': 0.061167990520042695, 'reg_alpha': 0.00016903608362152633, 'colsample_bytree': 0.8700038221327597, 'colsample_bynode': 0.5536251371089962, 'subsample': 0.8614140366150196, 'learning_rate': 0.02017917798294082, 'max_depth': 11, 'min_child_samples': 17, 'num_leaves': 30, 'n_estimators': 900}. Best is trial 14 with value: 0.6609567164843508.
# [I 2024-01-02 23:13:15,301] Trial 18 finished with value: 0.709234366910574 and parameters: {'reg_lambda': 0.005778936731144142, 'reg_alpha': 0.00010773567105977106, 'colsample_bytree': 0.7829732955951187, 'colsample_bynode': 0.6464180099557966, 'subsample': 0.9523546562524586, 'learning_rate': 0.004670848200798907, 'max_depth': 15, 'min_child_samples': 17, 'num_leaves': 18, 'n_estimators': 300}. Best is trial 14 with value: 0.6609567164843508.
# [I 2024-01-02 23:13:19,156] Trial 19 finished with value: 0.6639754012907522 and parameters: {'reg_lambda': 0.0012642350017431686, 'reg_alpha': 0.0034184896727914595, 'colsample_bytree': 0.6934144105279761, 'colsample_bynode': 0.5622750931161445, 'subsample': 0.9900504241017046, 'learning_rate': 0.021748964071185276, 'max_depth': 20, 'min_child_samples': 13, 'num_leaves': 26, 'n_estimators': 1300}. Best is trial 14 with value: 0.6609567164843508.
# [I 2024-01-02 23:13:21,352] A new study created in memory with name: no-name-e8c33d40-4190-4f0f-864c-d2e6019d239f
# [I 2024-01-02 23:13:24,469] Trial 0 finished with value: 0.6148898287485127 and parameters: {'reg_lambda': 0.02376166357536271, 'reg_alpha': 0.011843700464932166, 'colsample_bytree': 0.9716771451265684, 'colsample_bynode': 0.5209886856075701, 'subsample': 0.7491926914998847, 'learning_rate': 0.019814273852572232, 'max_depth': 5, 'min_child_samples': 13, 'num_leaves': 38, 'n_estimators': 1100}. Best is trial 0 with value: 0.6148898287485127.
# [I 2024-01-02 23:13:29,196] Trial 1 finished with value: 0.6046597579866068 and parameters: {'reg_lambda': 0.00012622623994555483, 'reg_alpha': 0.9661045313008466, 'colsample_bytree': 0.8547559620105326, 'colsample_bynode': 0.5262261216563485, 'subsample': 0.606201312227886, 'learning_rate': 0.004351604309022712, 'max_depth': 13, 'min_child_samples': 20, 'num_leaves': 18, 'n_estimators': 1500}. Best is trial 1 with value: 0.6046597579866068.
# [I 2024-01-02 23:13:32,625] Trial 2 finished with value: 0.9329480470770166 and parameters: {'reg_lambda': 2.0640212122524684, 'reg_alpha': 0.041829152369895026, 'colsample_bytree': 0.8027654884005031, 'colsample_bynode': 0.5308669010556266, 'subsample': 0.9195638782832927, 'learning_rate': 0.00013906766219169434, 'max_depth': 11, 'min_child_samples': 11, 'num_leaves': 30, 'n_estimators': 700}. Best is trial 1 with value: 0.6046597579866068.
# [I 2024-01-02 23:13:41,913] Trial 3 finished with value: 0.870394360202289 and parameters: {'reg_lambda': 0.016578764381298638, 'reg_alpha': 0.11793607002355379, 'colsample_bytree': 0.9463609624188996, 'colsample_bynode': 0.9580335969231869, 'subsample': 0.6263034611212841, 'learning_rate': 0.00017557612843192974, 'max_depth': 17, 'min_child_samples': 9, 'num_leaves': 38, 'n_estimators': 1300}. Best is trial 1 with value: 0.6046597579866068.
# [I 2024-01-02 23:13:45,277] Trial 4 finished with value: 0.6042005208116935 and parameters: {'reg_lambda': 0.0005764042688212926, 'reg_alpha': 8.3604763717978, 'colsample_bytree': 0.6714233408543512, 'colsample_bynode': 0.6280958631697837, 'subsample': 0.9702677013910654, 'learning_rate': 0.020022087774746625, 'max_depth': 7, 'min_child_samples': 15, 'num_leaves': 30, 'n_estimators': 1100}. Best is trial 4 with value: 0.6042005208116935.
# [I 2024-01-02 23:13:50,202] Trial 5 finished with value: 0.6200260165096362 and parameters: {'reg_lambda': 0.001056037575342193, 'reg_alpha': 0.0009397929964880262, 'colsample_bytree': 0.6730215988290648, 'colsample_bynode': 0.6996786215151782, 'subsample': 0.8543648672150483, 'learning_rate': 0.0017521253178432153, 'max_depth': 13, 'min_child_samples': 13, 'num_leaves': 26, 'n_estimators': 1300}. Best is trial 4 with value: 0.6042005208116935.
# [I 2024-01-02 23:13:51,718] Trial 6 finished with value: 0.7165372412857013 and parameters: {'reg_lambda': 2.3513715457795734, 'reg_alpha': 0.005022194554165304, 'colsample_bytree': 0.8166905824306777, 'colsample_bynode': 0.5833376783209681, 'subsample': 0.8409833390865625, 'learning_rate': 0.002745149168981338, 'max_depth': 17, 'min_child_samples': 9, 'num_leaves': 26, 'n_estimators': 300}. Best is trial 4 with value: 0.6042005208116935.
# [I 2024-01-02 23:13:52,856] Trial 7 finished with value: 0.8859302127795907 and parameters: {'reg_lambda': 0.0002744555477073684, 'reg_alpha': 0.0015788681708886589, 'colsample_bytree': 0.5257000028598992, 'colsample_bynode': 0.5839590642302892, 'subsample': 0.9766714068677618, 'learning_rate': 0.000659630699838869, 'max_depth': 7, 'min_child_samples': 20, 'num_leaves': 30, 'n_estimators': 300}. Best is trial 4 with value: 0.6042005208116935.
# [I 2024-01-02 23:13:57,358] Trial 8 finished with value: 0.6567593915306822 and parameters: {'reg_lambda': 0.36943646972682503, 'reg_alpha': 0.0003823361828336048, 'colsample_bytree': 0.9360898294070552, 'colsample_bynode': 0.7294080786039578, 'subsample': 0.9229530427016037, 'learning_rate': 0.0009303786888277312, 'max_depth': 20, 'min_child_samples': 15, 'num_leaves': 14, 'n_estimators': 1500}. Best is trial 4 with value: 0.6042005208116935.
# [I 2024-01-02 23:13:58,975] Trial 9 finished with value: 0.6011328087082474 and parameters: {'reg_lambda': 1.171678730097357, 'reg_alpha': 0.006420541253442793, 'colsample_bytree': 0.6364590972039118, 'colsample_bynode': 0.5415982272135822, 'subsample': 0.9552659501881953, 'learning_rate': 0.005174336404349947, 'max_depth': 13, 'min_child_samples': 9, 'num_leaves': 10, 'n_estimators': 900}. Best is trial 9 with value: 0.6011328087082474.
# [I 2024-01-02 23:14:01,225] Trial 10 finished with value: 0.6145045517683185 and parameters: {'reg_lambda': 6.943626399646853, 'reg_alpha': 0.00020327443474537173, 'colsample_bytree': 0.5044860204114444, 'colsample_bynode': 0.8152555841067508, 'subsample': 0.5025348549964337, 'learning_rate': 0.049715733790114985, 'max_depth': 15, 'min_child_samples': 17, 'num_leaves': 10, 'n_estimators': 1900}. Best is trial 9 with value: 0.6011328087082474.
# [I 2024-01-02 23:14:03,092] Trial 11 finished with value: 0.5940592263685694 and parameters: {'reg_lambda': 0.1598842267682895, 'reg_alpha': 5.01299046691241, 'colsample_bytree': 0.6692485360191109, 'colsample_bynode': 0.6661876249123565, 'subsample': 0.9762987388677982, 'learning_rate': 0.00956470938714817, 'max_depth': 7, 'min_child_samples': 7, 'num_leaves': 18, 'n_estimators': 700}. Best is trial 11 with value: 0.5940592263685694.
# [I 2024-01-02 23:14:05,250] Trial 12 finished with value: 0.6089560783300172 and parameters: {'reg_lambda': 0.24007096350485582, 'reg_alpha': 0.12777950753988135, 'colsample_bytree': 0.6665375432431582, 'colsample_bynode': 0.6455956674038473, 'subsample': 0.9736215641511852, 'learning_rate': 0.0071260294127345495, 'max_depth': 13, 'min_child_samples': 7, 'num_leaves': 18, 'n_estimators': 700}. Best is trial 11 with value: 0.5940592263685694.
# [I 2024-01-02 23:14:06,092] Trial 13 finished with value: 0.6124416946013218 and parameters: {'reg_lambda': 0.15754376731713762, 'reg_alpha': 7.467896265589499, 'colsample_bytree': 0.6013006009355433, 'colsample_bynode': 0.6678851199171019, 'subsample': 0.9985490943452262, 'learning_rate': 0.00668757768556177, 'max_depth': 9, 'min_child_samples': 7, 'num_leaves': 10, 'n_estimators': 500}. Best is trial 11 with value: 0.5940592263685694.
# [I 2024-01-02 23:14:08,180] Trial 14 finished with value: 0.6038444481780787 and parameters: {'reg_lambda': 0.08063627756433812, 'reg_alpha': 0.6745853443609912, 'colsample_bytree': 0.7343787497167814, 'colsample_bynode': 0.7560064213408214, 'subsample': 0.87180463536773, 'learning_rate': 0.010847423916005574, 'max_depth': 7, 'min_child_samples': 7, 'num_leaves': 18, 'n_estimators': 700}. Best is trial 11 with value: 0.5940592263685694.
# [I 2024-01-02 23:14:08,501] Trial 15 finished with value: 0.8461087676201057 and parameters: {'reg_lambda': 0.7131431634054229, 'reg_alpha': 0.005505785295949578, 'colsample_bytree': 0.5990419167737644, 'colsample_bynode': 0.5978639335700962, 'subsample': 0.7944791871662275, 'learning_rate': 0.003132549858664573, 'max_depth': 20, 'min_child_samples': 9, 'num_leaves': 14, 'n_estimators': 100}. Best is trial 11 with value: 0.5940592263685694.
# [I 2024-01-02 23:14:10,685] Trial 16 finished with value: 0.6125554466673567 and parameters: {'reg_lambda': 7.984452161527289, 'reg_alpha': 0.020832255430212793, 'colsample_bytree': 0.732964161897483, 'colsample_bynode': 0.6676563574658698, 'subsample': 0.9219926593416121, 'learning_rate': 0.01118418959947167, 'max_depth': 9, 'min_child_samples': 11, 'num_leaves': 14, 'n_estimators': 900}. Best is trial 11 with value: 0.5940592263685694.
# [I 2024-01-02 23:14:13,449] Trial 17 finished with value: 0.6430416624136268 and parameters: {'reg_lambda': 0.055220025869514244, 'reg_alpha': 0.00010565857048846862, 'colsample_bytree': 0.5825998958907325, 'colsample_bynode': 0.5127879096788482, 'subsample': 0.7874977206612079, 'learning_rate': 0.0017444045158119294, 'max_depth': 11, 'min_child_samples': 17, 'num_leaves': 22, 'n_estimators': 900}. Best is trial 11 with value: 0.5940592263685694.
# [I 2024-01-02 23:14:14,449] Trial 18 finished with value: 0.6215748502362671 and parameters: {'reg_lambda': 0.7903085481394915, 'reg_alpha': 0.0022609096162337543, 'colsample_bytree': 0.6975463095510983, 'colsample_bynode': 0.5959087418246156, 'subsample': 0.9148950410030299, 'learning_rate': 0.005138014675929674, 'max_depth': 15, 'min_child_samples': 9, 'num_leaves': 10, 'n_estimators': 500}. Best is trial 11 with value: 0.5940592263685694.
# [I 2024-01-02 23:14:18,521] Trial 19 finished with value: 0.6142397362751648 and parameters: {'reg_lambda': 0.009376200301784071, 'reg_alpha': 0.0537795472218609, 'colsample_bytree': 0.6303217194304629, 'colsample_bynode': 0.771893098846502, 'subsample': 0.8792297329162537, 'learning_rate': 0.03074074671088406, 'max_depth': 5, 'min_child_samples': 7, 'num_leaves': 22, 'n_estimators': 1900}. Best is trial 11 with value: 0.5940592263685694.
# [I 2024-01-02 23:14:20,439] A new study created in memory with name: no-name-61a82357-0eed-4d6e-95e3-92fb4daf150d
# [I 2024-01-02 23:14:23,860] Trial 0 finished with value: 0.5609265365787983 and parameters: {'reg_lambda': 6.994867480192789, 'reg_alpha': 0.33518563698162146, 'colsample_bytree': 0.8072069158530855, 'colsample_bynode': 0.9634723868503964, 'subsample': 0.8045708212248472, 'learning_rate': 0.047349862700189774, 'max_depth': 15, 'min_child_samples': 20, 'num_leaves': 14, 'n_estimators': 1900}. Best is trial 0 with value: 0.5609265365787983.
# [I 2024-01-02 23:14:26,197] Trial 1 finished with value: 0.8135592984974895 and parameters: {'reg_lambda': 6.396043176824779, 'reg_alpha': 0.0005780171749304178, 'colsample_bytree': 0.9524635762938192, 'colsample_bynode': 0.8714984770691551, 'subsample': 0.9672249053767709, 'learning_rate': 0.00045796143063953033, 'max_depth': 15, 'min_child_samples': 11, 'num_leaves': 18, 'n_estimators': 700}. Best is trial 0 with value: 0.5609265365787983.
# [I 2024-01-02 23:14:27,894] Trial 2 finished with value: 0.5546549493978927 and parameters: {'reg_lambda': 0.003288010802944866, 'reg_alpha': 0.8461154411499944, 'colsample_bytree': 0.6832490558150874, 'colsample_bynode': 0.8060887640639193, 'subsample': 0.8824380686778717, 'learning_rate': 0.040193261404575194, 'max_depth': 7, 'min_child_samples': 20, 'num_leaves': 38, 'n_estimators': 500}. Best is trial 2 with value: 0.5546549493978927.
# [I 2024-01-02 23:14:34,543] Trial 3 finished with value: 0.5501949195679472 and parameters: {'reg_lambda': 1.2069000634226645, 'reg_alpha': 0.07605880565536438, 'colsample_bytree': 0.7933248193970357, 'colsample_bynode': 0.9552715984049236, 'subsample': 0.6277312500032834, 'learning_rate': 0.0071424312694052736, 'max_depth': 15, 'min_child_samples': 15, 'num_leaves': 38, 'n_estimators': 1300}. Best is trial 3 with value: 0.5501949195679472.
# [I 2024-01-02 23:14:38,756] Trial 4 finished with value: 0.5426799840997379 and parameters: {'reg_lambda': 0.0049135784353781355, 'reg_alpha': 0.0008706992873487497, 'colsample_bytree': 0.7280916587675099, 'colsample_bynode': 0.9946997425383122, 'subsample': 0.8614448398508194, 'learning_rate': 0.005738554558406365, 'max_depth': 5, 'min_child_samples': 7, 'num_leaves': 30, 'n_estimators': 1900}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:14:45,182] Trial 5 finished with value: 0.6217831364322878 and parameters: {'reg_lambda': 4.527168262356042, 'reg_alpha': 0.016358577355524408, 'colsample_bytree': 0.7995883202535183, 'colsample_bynode': 0.9771996741913249, 'subsample': 0.5047015227420952, 'learning_rate': 0.0006874870457220506, 'max_depth': 13, 'min_child_samples': 9, 'num_leaves': 26, 'n_estimators': 1700}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:14:51,159] Trial 6 finished with value: 0.5496099329855675 and parameters: {'reg_lambda': 0.556820325479993, 'reg_alpha': 0.0018119213369208146, 'colsample_bytree': 0.6908042541942575, 'colsample_bynode': 0.822050106645997, 'subsample': 0.8252517280876579, 'learning_rate': 0.01648015019844639, 'max_depth': 15, 'min_child_samples': 7, 'num_leaves': 38, 'n_estimators': 1300}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:14:54,876] Trial 7 finished with value: 0.5455114855673459 and parameters: {'reg_lambda': 0.0022484035887197335, 'reg_alpha': 0.005591376279179134, 'colsample_bytree': 0.9595596816602251, 'colsample_bynode': 0.9723920296818295, 'subsample': 0.8254901515661872, 'learning_rate': 0.0015436697989975666, 'max_depth': 17, 'min_child_samples': 20, 'num_leaves': 10, 'n_estimators': 1900}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:14:58,329] Trial 8 finished with value: 0.5655410111419783 and parameters: {'reg_lambda': 0.010429225899562621, 'reg_alpha': 0.423581513436133, 'colsample_bytree': 0.5351847305075639, 'colsample_bynode': 0.6969422218483223, 'subsample': 0.6744681258892549, 'learning_rate': 0.00144603819304533, 'max_depth': 11, 'min_child_samples': 7, 'num_leaves': 18, 'n_estimators': 1500}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:00,563] Trial 9 finished with value: 0.5480024349896121 and parameters: {'reg_lambda': 0.000871912317817309, 'reg_alpha': 0.07361562776065746, 'colsample_bytree': 0.6046689403205165, 'colsample_bynode': 0.5413898984394773, 'subsample': 0.7747072523026338, 'learning_rate': 0.021552208972928123, 'max_depth': 13, 'min_child_samples': 20, 'num_leaves': 18, 'n_estimators': 1100}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:02,433] Trial 10 finished with value: 0.8763360539860087 and parameters: {'reg_lambda': 0.00012843420572884284, 'reg_alpha': 0.00012579023991691923, 'colsample_bytree': 0.5088482637792631, 'colsample_bynode': 0.7108216417500948, 'subsample': 0.9970144697038756, 'learning_rate': 0.00018404879093355107, 'max_depth': 5, 'min_child_samples': 17, 'num_leaves': 30, 'n_estimators': 900}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:02,785] Trial 11 finished with value: 0.8085317775768711 and parameters: {'reg_lambda': 0.05214164280111238, 'reg_alpha': 0.005415519420493952, 'colsample_bytree': 0.9721013222003805, 'colsample_bynode': 0.9798207867145287, 'subsample': 0.8733260466338587, 'learning_rate': 0.0034742862745507836, 'max_depth': 17, 'min_child_samples': 13, 'num_leaves': 10, 'n_estimators': 100}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:12,369] Trial 12 finished with value: 0.5439121992451197 and parameters: {'reg_lambda': 0.03016458544149262, 'reg_alpha': 0.0024651332088446265, 'colsample_bytree': 0.9260132845525496, 'colsample_bynode': 0.9012514516878207, 'subsample': 0.909358368721245, 'learning_rate': 0.0036226017531565307, 'max_depth': 20, 'min_child_samples': 7, 'num_leaves': 30, 'n_estimators': 1900}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:20,417] Trial 13 finished with value: 0.5434915458810238 and parameters: {'reg_lambda': 0.04296029283249454, 'reg_alpha': 0.0004236681653193231, 'colsample_bytree': 0.8716237560362126, 'colsample_bynode': 0.8949260546002389, 'subsample': 0.907323212537452, 'learning_rate': 0.004838608447409694, 'max_depth': 20, 'min_child_samples': 7, 'num_leaves': 30, 'n_estimators': 1700}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:24,319] Trial 14 finished with value: 0.5458601619415229 and parameters: {'reg_lambda': 0.10475607358400252, 'reg_alpha': 0.00010868507047954004, 'colsample_bytree': 0.8735479779282913, 'colsample_bynode': 0.8920023238765006, 'subsample': 0.9281795724187172, 'learning_rate': 0.007699283091392006, 'max_depth': 5, 'min_child_samples': 7, 'num_leaves': 30, 'n_estimators': 1500}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:29,888] Trial 15 finished with value: 0.5613910719652295 and parameters: {'reg_lambda': 0.01628521673622133, 'reg_alpha': 8.712977303672305, 'colsample_bytree': 0.8649013603447316, 'colsample_bynode': 0.9012930053823781, 'subsample': 0.959244792719891, 'learning_rate': 0.006204931690483343, 'max_depth': 9, 'min_child_samples': 7, 'num_leaves': 26, 'n_estimators': 1700}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:37,319] Trial 16 finished with value: 0.5482325560922631 and parameters: {'reg_lambda': 0.11992712471012124, 'reg_alpha': 0.0005007301724867577, 'colsample_bytree': 0.7328302847107402, 'colsample_bynode': 0.9972670075979698, 'subsample': 0.874879081738703, 'learning_rate': 0.002562691394865921, 'max_depth': 20, 'min_child_samples': 17, 'num_leaves': 34, 'n_estimators': 1700}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:40,083] Trial 17 finished with value: 0.551381633582627 and parameters: {'reg_lambda': 0.007942122883782944, 'reg_alpha': 0.0005442124058204115, 'colsample_bytree': 0.8754575168616305, 'colsample_bynode': 0.8096447110249279, 'subsample': 0.7244828156043834, 'learning_rate': 0.012717195976244142, 'max_depth': 5, 'min_child_samples': 15, 'num_leaves': 22, 'n_estimators': 1300}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:48,355] Trial 18 finished with value: 0.5500362750636657 and parameters: {'reg_lambda': 0.24624288799561175, 'reg_alpha': 0.0012277137635055546, 'colsample_bytree': 0.9969809042151292, 'colsample_bynode': 0.9274664734070427, 'subsample': 0.9985177114304224, 'learning_rate': 0.004994381946280002, 'max_depth': 20, 'min_child_samples': 13, 'num_leaves': 34, 'n_estimators': 1500}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:48,789] Trial 19 finished with value: 0.6310028915116926 and parameters: {'reg_lambda': 0.026337415426718233, 'reg_alpha': 0.00025432667597078204, 'colsample_bytree': 0.7415462904907306, 'colsample_bynode': 0.8579889153950929, 'subsample': 0.9237707964799753, 'learning_rate': 0.010583076030309568, 'max_depth': 11, 'min_child_samples': 9, 'num_leaves': 22, 'n_estimators': 100}. Best is trial 4 with value: 0.5426799840997379.
# [I 2024-01-02 23:15:52,902] A new study created in memory with name: no-name-c1ce48f9-9d15-49bc-8a4c-eefb7f511cef
# [I 2024-01-02 23:15:57,330] Trial 0 finished with value: 0.7020716468959487 and parameters: {'reg_lambda': 3.2765351894197097, 'reg_alpha': 0.926825766262868, 'colsample_bytree': 0.6580191969111273, 'colsample_bynode': 0.6469370472540166, 'subsample': 0.592018176798152, 'learning_rate': 0.0010567333799080109, 'max_depth': 11, 'min_child_samples': 13, 'num_leaves': 18, 'n_estimators': 1500}. Best is trial 0 with value: 0.7020716468959487.
# [I 2024-01-02 23:16:00,299] Trial 1 finished with value: 0.6498787704690069 and parameters: {'reg_lambda': 0.44402592652270384, 'reg_alpha': 0.0006551104796104036, 'colsample_bytree': 0.9120298858743249, 'colsample_bynode': 0.632598670703523, 'subsample': 0.6677847250650011, 'learning_rate': 0.004334717704130562, 'max_depth': 9, 'min_child_samples': 7, 'num_leaves': 18, 'n_estimators': 700}. Best is trial 1 with value: 0.6498787704690069.
# [I 2024-01-02 23:16:05,901] Trial 2 finished with value: 0.9932191315635243 and parameters: {'reg_lambda': 0.016478859067970204, 'reg_alpha': 0.0019674446838734796, 'colsample_bytree': 0.8268586898260828, 'colsample_bynode': 0.9357673251991778, 'subsample': 0.9799994125701382, 'learning_rate': 0.0001765384184162349, 'max_depth': 11, 'min_child_samples': 17, 'num_leaves': 38, 'n_estimators': 900}. Best is trial 1 with value: 0.6498787704690069.
# [I 2024-01-02 23:16:07,173] Trial 3 finished with value: 0.807240517766236 and parameters: {'reg_lambda': 0.0014781320194472694, 'reg_alpha': 2.7478452953861194, 'colsample_bytree': 0.5591023397542582, 'colsample_bynode': 0.6298517296177611, 'subsample': 0.7869971883141044, 'learning_rate': 0.0014495504628161643, 'max_depth': 17, 'min_child_samples': 17, 'num_leaves': 18, 'n_estimators': 500}. Best is trial 1 with value: 0.6498787704690069.
# [I 2024-01-02 23:16:13,475] Trial 4 finished with value: 0.6556500277608903 and parameters: {'reg_lambda': 0.005701156228861735, 'reg_alpha': 0.0006103770223506626, 'colsample_bytree': 0.9650689864475592, 'colsample_bynode': 0.6907204471342453, 'subsample': 0.7269165943534162, 'learning_rate': 0.015793817521560637, 'max_depth': 7, 'min_child_samples': 11, 'num_leaves': 22, 'n_estimators': 1900}. Best is trial 1 with value: 0.6498787704690069.
# [I 2024-01-02 23:16:16,009] Trial 5 finished with value: 1.0174747361711711 and parameters: {'reg_lambda': 1.5488915039017872, 'reg_alpha': 0.5290896826677456, 'colsample_bytree': 0.5439295001249083, 'colsample_bynode': 0.6473225605572022, 'subsample': 0.6121383855887065, 'learning_rate': 0.00016197181954206248, 'max_depth': 13, 'min_child_samples': 9, 'num_leaves': 26, 'n_estimators': 700}. Best is trial 1 with value: 0.6498787704690069.
# ...
# [I 2024-01-02 23:55:05,913] Trial 5 finished with value: 0.6160514399156242 and parameters: {'reg_lambda': 0.04267067633417794, 'reg_alpha': 0.008631198783958325, 'colsample_bytree': 0.666361715015118, 'colsample_bynode': 0.559433344802317, 'subsample': 0.6779623471420049, 'learning_rate': 0.0028187292345329645, 'max_depth': 13, 'min_child_samples': 9, 'num_leaves': 22, 'n_estimators': 1300}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:10,398] Trial 6 finished with value: 0.753093592314735 and parameters: {'reg_lambda': 6.828861303825388, 'reg_alpha': 0.0010451627184194876, 'colsample_bytree': 0.564560434756473, 'colsample_bynode': 0.5663005700986095, 'subsample': 0.9631787946784356, 'learning_rate': 0.00038162298093159395, 'max_depth': 20, 'min_child_samples': 20, 'num_leaves': 22, 'n_estimators': 1900}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:13,138] Trial 7 finished with value: 0.6283459832731444 and parameters: {'reg_lambda': 0.5068560483463901, 'reg_alpha': 1.200588554351336, 'colsample_bytree': 0.7645405291247873, 'colsample_bynode': 0.675738663791539, 'subsample': 0.8491707815107108, 'learning_rate': 0.006720911111704662, 'max_depth': 5, 'min_child_samples': 9, 'num_leaves': 18, 'n_estimators': 1300}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:16,033] Trial 8 finished with value: 0.640891662362691 and parameters: {'reg_lambda': 0.3235683529666198, 'reg_alpha': 0.0002039035762703941, 'colsample_bytree': 0.5524712984875361, 'colsample_bynode': 0.7224164740129952, 'subsample': 0.8980824623248622, 'learning_rate': 0.001986309874442898, 'max_depth': 17, 'min_child_samples': 15, 'num_leaves': 26, 'n_estimators': 900}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:22,533] Trial 9 finished with value: 0.6183995461309679 and parameters: {'reg_lambda': 0.3839500648910047, 'reg_alpha': 1.7827805448156744, 'colsample_bytree': 0.610441254482731, 'colsample_bynode': 0.6808537872231226, 'subsample': 0.5634388054372736, 'learning_rate': 0.0012687229310943278, 'max_depth': 20, 'min_child_samples': 20, 'num_leaves': 34, 'n_estimators': 1900}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:25,068] Trial 10 finished with value: 0.6401742649832838 and parameters: {'reg_lambda': 0.02048561442671219, 'reg_alpha': 0.029499428228339064, 'colsample_bytree': 0.6623865842021864, 'colsample_bynode': 0.509706558033103, 'subsample': 0.6511685935528235, 'learning_rate': 0.0254517591153685, 'max_depth': 13, 'min_child_samples': 11, 'num_leaves': 38, 'n_estimators': 500}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:29,020] Trial 11 finished with value: 0.6268416010807828 and parameters: {'reg_lambda': 0.10816682894002602, 'reg_alpha': 7.206777143723871, 'colsample_bytree': 0.6539024028984306, 'colsample_bynode': 0.634280701498884, 'subsample': 0.5070328415220692, 'learning_rate': 0.003804379464534304, 'max_depth': 20, 'min_child_samples': 20, 'num_leaves': 38, 'n_estimators': 1300}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:33,856] Trial 12 finished with value: 0.633155338404591 and parameters: {'reg_lambda': 0.056020492930590964, 'reg_alpha': 0.06841017331901039, 'colsample_bytree': 0.6413720729548621, 'colsample_bynode': 0.6327744156130966, 'subsample': 0.5945829977067602, 'learning_rate': 0.037348421082553596, 'max_depth': 11, 'min_child_samples': 13, 'num_leaves': 30, 'n_estimators': 1500}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:37,085] Trial 13 finished with value: 0.7223215714701439 and parameters: {'reg_lambda': 0.006589748292037374, 'reg_alpha': 0.017336377486174167, 'colsample_bytree': 0.7074560821586291, 'colsample_bynode': 0.615445289047321, 'subsample': 0.6618855575577407, 'learning_rate': 0.0011927444099476168, 'max_depth': 13, 'min_child_samples': 20, 'num_leaves': 34, 'n_estimators': 700}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:40,403] Trial 14 finished with value: 0.6266340977679742 and parameters: {'reg_lambda': 0.18871478206871914, 'reg_alpha': 0.008307448098584438, 'colsample_bytree': 0.5989754632745233, 'colsample_bynode': 0.5018021151870709, 'subsample': 0.5353550040113478, 'learning_rate': 0.006743576385465051, 'max_depth': 7, 'min_child_samples': 9, 'num_leaves': 18, 'n_estimators': 1500}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:47,124] Trial 15 finished with value: 0.6451852711918514 and parameters: {'reg_lambda': 0.6849463523651804, 'reg_alpha': 0.0981862860136176, 'colsample_bytree': 0.7320956643776049, 'colsample_bynode': 0.6871216396385141, 'subsample': 0.5883155437902032, 'learning_rate': 0.0010534814850324415, 'max_depth': 20, 'min_child_samples': 11, 'num_leaves': 26, 'n_estimators': 1700}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:49,403] Trial 16 finished with value: 0.6235216393245692 and parameters: {'reg_lambda': 0.047185478063753325, 'reg_alpha': 0.004623856196233372, 'colsample_bytree': 0.5038908127090043, 'colsample_bynode': 0.5977494914984383, 'subsample': 0.7351746036847214, 'learning_rate': 0.003576271831349376, 'max_depth': 7, 'min_child_samples': 17, 'num_leaves': 18, 'n_estimators': 1100}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:52,961] Trial 17 finished with value: 0.6844729169719005 and parameters: {'reg_lambda': 0.1200716182888966, 'reg_alpha': 0.08012322403605959, 'colsample_bytree': 0.5961652300172282, 'colsample_bynode': 0.8337863772523744, 'subsample': 0.6833076661468548, 'learning_rate': 0.0007293808698670145, 'max_depth': 5, 'min_child_samples': 13, 'num_leaves': 34, 'n_estimators': 1500}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:55:56,569] Trial 18 finished with value: 0.6386437346603088 and parameters: {'reg_lambda': 1.1381681139378559, 'reg_alpha': 0.31025484662938146, 'colsample_bytree': 0.6624937539206073, 'colsample_bynode': 0.5494854830417069, 'subsample': 0.8048811938674548, 'learning_rate': 0.048804160858733486, 'max_depth': 9, 'min_child_samples': 9, 'num_leaves': 34, 'n_estimators': 900}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:56:03,175] Trial 19 finished with value: 0.6309333893844351 and parameters: {'reg_lambda': 0.0037363325515151, 'reg_alpha': 0.015132059982506755, 'colsample_bytree': 0.778919648999034, 'colsample_bynode': 0.6758412461441002, 'subsample': 0.5846943350644954, 'learning_rate': 0.004043609500370839, 'max_depth': 11, 'min_child_samples': 20, 'num_leaves': 26, 'n_estimators': 1900}. Best is trial 5 with value: 0.6160514399156242.
# [I 2024-01-02 23:56:07,368] A new study created in memory with name: no-name-d2791f37-fbd0-4112-bdab-d8df338c5e97
# [I 2024-01-02 23:56:12,239] Trial 0 finished with value: 0.597090222038555 and parameters: {'reg_lambda': 0.0003998893402746501, 'reg_alpha': 6.802479789991319, 'colsample_bytree': 0.6590843464470851, 'colsample_bynode': 0.7691578238990691, 'subsample': 0.7174145185485508, 'learning_rate': 0.0030239027946126654, 'max_depth': 7, 'min_child_samples': 9, 'num_leaves': 34, 'n_estimators': 1300}. Best is trial 0 with value: 0.597090222038555.
# [I 2024-01-02 23:56:19,756] Trial 1 finished with value: 0.8837028983979768 and parameters: {'reg_lambda': 0.011236789109071759, 'reg_alpha': 0.18845657843433125, 'colsample_bytree': 0.5822884369214104, 'colsample_bynode': 0.874727362352612, 'subsample': 0.609878152021332, 'learning_rate': 0.00016267303200026995, 'max_depth': 7, 'min_child_samples': 20, 'num_leaves': 38, 'n_estimators': 1700}. Best is trial 0 with value: 0.597090222038555.
# [I 2024-01-02 23:56:21,887] Trial 2 finished with value: 0.6030263039281613 and parameters: {'reg_lambda': 0.0006753273573726832, 'reg_alpha': 0.7489616134677297, 'colsample_bytree': 0.9457869340351197, 'colsample_bynode': 0.8421643012252281, 'subsample': 0.9671187229784132, 'learning_rate': 0.012137825960286735, 'max_depth': 17, 'min_child_samples': 15, 'num_leaves': 14, 'n_estimators': 700}. Best is trial 0 with value: 0.597090222038555.
# [I 2024-01-02 23:56:24,939] Trial 3 finished with value: 0.878449950824389 and parameters: {'reg_lambda': 0.001802365383790801, 'reg_alpha': 0.0017405587800433835, 'colsample_bytree': 0.7646240188470647, 'colsample_bynode': 0.9137661828623124, 'subsample': 0.8450221498915795, 'learning_rate': 0.0002757515977574208, 'max_depth': 20, 'min_child_samples': 17, 'num_leaves': 14, 'n_estimators': 1100}. Best is trial 0 with value: 0.597090222038555.
# [I 2024-01-02 23:56:25,239] Trial 4 finished with value: 0.9448436700667946 and parameters: {'reg_lambda': 0.00015224730208569876, 'reg_alpha': 0.960592890305751, 'colsample_bytree': 0.5737908281778726, 'colsample_bynode': 0.7393713856879061, 'subsample': 0.8631252979181728, 'learning_rate': 0.001584844344421483, 'max_depth': 15, 'min_child_samples': 17, 'num_leaves': 10, 'n_estimators': 100}. Best is trial 0 with value: 0.597090222038555.
# [I 2024-01-02 23:56:29,884] Trial 5 finished with value: 0.6097887010141314 and parameters: {'reg_lambda': 0.0001287404717287122, 'reg_alpha': 0.0005876002873963882, 'colsample_bytree': 0.890955901768451, 'colsample_bynode': 0.5621568215685373, 'subsample': 0.9384886520172352, 'learning_rate': 0.018328413562703084, 'max_depth': 11, 'min_child_samples': 15, 'num_leaves': 34, 'n_estimators': 900}. Best is trial 0 with value: 0.597090222038555.
# [I 2024-01-02 23:56:33,156] Trial 6 finished with value: 0.6103548802261481 and parameters: {'reg_lambda': 0.00013733124707196462, 'reg_alpha': 0.04147284812989904, 'colsample_bytree': 0.5904650903912085, 'colsample_bynode': 0.7504655297916634, 'subsample': 0.6330340549648146, 'learning_rate': 0.014944318138555639, 'max_depth': 7, 'min_child_samples': 17, 'num_leaves': 22, 'n_estimators': 1300}. Best is trial 0 with value: 0.597090222038555.
# [I 2024-01-02 23:56:35,247] Trial 7 finished with value: 0.5882653272165724 and parameters: {'reg_lambda': 0.00024137471302626678, 'reg_alpha': 0.014375306327809608, 'colsample_bytree': 0.9028915440623809, 'colsample_bynode': 0.7918784767332584, 'subsample': 0.5128672603573754, 'learning_rate': 0.004109551697630944, 'max_depth': 9, 'min_child_samples': 17, 'num_leaves': 10, 'n_estimators': 900}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:56:40,715] Trial 8 finished with value: 0.9430917027591919 and parameters: {'reg_lambda': 0.04277889854253724, 'reg_alpha': 0.0016029275695088254, 'colsample_bytree': 0.5403163983833781, 'colsample_bynode': 0.7448702414269347, 'subsample': 0.5182919306497001, 'learning_rate': 0.00011419113266539655, 'max_depth': 15, 'min_child_samples': 7, 'num_leaves': 30, 'n_estimators': 1300}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:56:49,716] Trial 9 finished with value: 0.615850758469981 and parameters: {'reg_lambda': 0.00040953430556466946, 'reg_alpha': 0.0022579016948725927, 'colsample_bytree': 0.9382556212994366, 'colsample_bynode': 0.6072123306917343, 'subsample': 0.6523186703664096, 'learning_rate': 0.04043908074854318, 'max_depth': 17, 'min_child_samples': 7, 'num_leaves': 38, 'n_estimators': 1500}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:56:51,098] Trial 10 finished with value: 0.7206776780418798 and parameters: {'reg_lambda': 0.9910157161858572, 'reg_alpha': 0.00012035049093165668, 'colsample_bytree': 0.8334132955697681, 'colsample_bynode': 0.9997566210301818, 'subsample': 0.5335503940641975, 'learning_rate': 0.0029041524139268977, 'max_depth': 9, 'min_child_samples': 13, 'num_leaves': 22, 'n_estimators': 300}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:56:55,885] Trial 11 finished with value: 0.5904131656556681 and parameters: {'reg_lambda': 0.0020936414534752, 'reg_alpha': 8.621532623849754, 'colsample_bytree': 0.7036203717873206, 'colsample_bynode': 0.6717951558166256, 'subsample': 0.7463790543060139, 'learning_rate': 0.002975925008278789, 'max_depth': 5, 'min_child_samples': 9, 'num_leaves': 26, 'n_estimators': 1900}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:57:01,903] Trial 12 finished with value: 0.6155231860912814 and parameters: {'reg_lambda': 0.0027994781330513167, 'reg_alpha': 0.01723627825779827, 'colsample_bytree': 0.7412859956862528, 'colsample_bynode': 0.649619430768402, 'subsample': 0.7412614837799225, 'learning_rate': 0.0011656507200863153, 'max_depth': 5, 'min_child_samples': 11, 'num_leaves': 26, 'n_estimators': 1900}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:57:04,741] Trial 13 finished with value: 0.5930480975459104 and parameters: {'reg_lambda': 0.004899831915042687, 'reg_alpha': 0.015882377684099856, 'colsample_bytree': 0.989983334910157, 'colsample_bynode': 0.6642109420544684, 'subsample': 0.5058197654798484, 'learning_rate': 0.005258552209332417, 'max_depth': 9, 'min_child_samples': 9, 'num_leaves': 18, 'n_estimators': 700}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:57:06,303] Trial 14 finished with value: 0.824580261336108 and parameters: {'reg_lambda': 0.07347191872228571, 'reg_alpha': 6.8917878564788095, 'colsample_bytree': 0.814551611765104, 'colsample_bynode': 0.6618057581770201, 'subsample': 0.7970070218769292, 'learning_rate': 0.0008811034811132538, 'max_depth': 5, 'min_child_samples': 9, 'num_leaves': 26, 'n_estimators': 500}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:57:09,608] Trial 15 finished with value: 0.6014949494408338 and parameters: {'reg_lambda': 0.0016649030056234892, 'reg_alpha': 0.12200489673491607, 'colsample_bytree': 0.6866610496865501, 'colsample_bynode': 0.5074155317766273, 'subsample': 0.7024352675499638, 'learning_rate': 0.005777341987705137, 'max_depth': 13, 'min_child_samples': 11, 'num_leaves': 10, 'n_estimators': 1900}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:57:13,040] Trial 16 finished with value: 0.7465481287312591 and parameters: {'reg_lambda': 0.01314970242998833, 'reg_alpha': 1.0406784560934113, 'colsample_bytree': 0.8609311022067899, 'colsample_bynode': 0.8048032538796185, 'subsample': 0.5615985434605253, 'learning_rate': 0.0008565410926017304, 'max_depth': 9, 'min_child_samples': 13, 'num_leaves': 18, 'n_estimators': 900}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:57:17,832] Trial 17 finished with value: 0.7495043738365622 and parameters: {'reg_lambda': 0.0010795428513272593, 'reg_alpha': 0.014092097490124182, 'colsample_bytree': 0.7851260988849751, 'colsample_bynode': 0.7014989513478436, 'subsample': 0.6812495996441638, 'learning_rate': 0.0004904953214787863, 'max_depth': 5, 'min_child_samples': 20, 'num_leaves': 30, 'n_estimators': 1500}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:57:21,101] Trial 18 finished with value: 0.6122357489928459 and parameters: {'reg_lambda': 0.004487089509356016, 'reg_alpha': 8.714224976981923, 'colsample_bytree': 0.7280653518544413, 'colsample_bynode': 0.8073996372378501, 'subsample': 0.5734553696974114, 'learning_rate': 0.0021158152233799934, 'max_depth': 20, 'min_child_samples': 9, 'num_leaves': 18, 'n_estimators': 1100}. Best is trial 7 with value: 0.5882653272165724.
# [I 2024-01-02 23:57:24,023] Trial 19 finished with value: 0.6072570813791556 and parameters: {'reg_lambda': 8.745397811417009, 'reg_alpha': 0.06789830291580727, 'colsample_bytree': 0.870143140416721, 'colsample_bynode': 0.7115545067809109, 'subsample': 0.6041256001400341, 'learning_rate': 0.005003812109926446, 'max_depth': 11, 'min_child_samples': 17, 'num_leaves': 30, 'n_estimators': 500}. Best is trial 7 with value: 0.5882653272165724.

# %%
print('OOF metric LGBM = {:.5f}'.format(metrics.mean_squared_error(train_feats[target_col], 
                                                                   OOF_SCORE,
                                                                   squared=False)))
# Out:
# OOF metric LGBM = 0.60957

# %%
import pickle

with open(f'{dir_to_save}/OOF_base_lgb.pkl', 'wb') as f:
    pickle.dump(OOF_SCORE, f)

# %%
f, ax = plt.subplots(figsize=(6, 6))
ax.scatter(OOF_SCORE, train_feats['score'])
add_identity(ax, color='r', ls='--')
# ax.scatter(stds, train_scores_df['score']-means)
plt.ylabel('True Values')
plt.xlabel('Predictions')

plt.show()
